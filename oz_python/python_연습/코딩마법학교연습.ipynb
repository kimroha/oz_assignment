# %%
# 주석은 이렇게 하는거다
print("진짜 안보이낭")
# print("신기하다")
# Out:
# 진짜 안보이낭

# %%
for 동물 in ("토끼","사자","푸바오"):
  print(동물)
  print("보러갈래요?")
# Out:
# 토끼
# 보러갈래요?
# 사자
# 보러갈래요?
# 푸바오
# 보러갈래요?

# %%
# 코딩마법학교 연습
a = "a journey to happiness"
print( a[-9:] )
# Out:
# happiness

# %%
# 코딩마법학교 연습
a = "가을 하늘 아래 우리는"
print(a[9:])
print(a[:2])
# Out:
# 우리는
# 가을

# %%
# 코딩마법학교 연습
a = "call my name"
print(a[-4:])
# Out:
# name

# %%
# 코딩마법학교 3-2 10번문제 오답
# 원본 날짜 문자열
date = "2019-06-29"

# 문자열 슬라이싱으로 연도, 월, 일 추출
year = date[:4]
month = date[6:7]
day = date[8:]

# 출력
print(year + "년")
print(month + "월")
print(day + "일")
# Out:
# 2019년
# 6월
# 29일

# %%
# 코딩학교 연습 

# 그의 이름은 홍길동입니다.
# 나이는 20입니다.
# 좋아하는 음식은 카레입니다.

name = "홍길동"
age = 20
food = "카레"

sentence = "그의 이름은 %s입니다. \n나이는 %d입니다. \n좋아하는 음식은 %s입니다." %(name, age, food)
print(sentence)
# Out:
# 그의 이름은 홍길동입니다.
# 나이는 20입니다.
# 좋아하는 음식은 카레입니다.

# %%
# 예제만들기
name = "김철수"
age = 16
food = "라면"
sentence = "%s 학생은 나이가 %d입니다.\n%s 학생이 좋아하는 음식은 %s입니다."%(name, age, name, food)
print(sentence)
# Out:
# 김철수 학생은 나이가 16입니다.
# 김철수 학생이 좋아하는 음식은 라면입니다.

# %%
#예제연습
name = "김석원"
rank = 16
total = 200
grade = "우"
sentence = "%s 학생은 전체 %d명 중 %d등을 했습니다.\n그는 상위 %f%%였지만, 성적은 %c를 받았습니다."%(name, total, rank, (rank/total*100), grade)
print(sentence)
# Out:
# 김석원 학생은 전체 200명 중 16등을 했습니다.
# 그는 상위 8.000000%였지만, 성적은 우를 받았습니다.

# %%
# 예제연습
weapon = "도끼"
damage = 200
monster_name = "가고일"
monster_hp = 850
sentence = "%s로 %d의 피해를 입혔습니다.\n현재 %s의 체력은 %f%% 남았습니다."%(weapon, damage, monster_name, ((monster_hp-damage)/monster_hp)*100)
print(sentence)
# Out:
# 도끼로 200의 피해를 입혔습니다.
# 현재 가고일의 체력은 76.470588% 남았습니다.
